# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import numpy as np

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
filtered_df = application_df.drop(columns=["NAME", "EIN"])
filtered_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
filtered_cat = filtered_df.dtypes[filtered_df.dtypes == "object"].index.tolist()
filtered_cat
# Out:
# ['APPLICATION_TYPE',
#  'AFFILIATION',
#  'CLASSIFICATION',
#  'USE_CASE',
#  'ORGANIZATION',
#  'INCOME_AMT',
#  'SPECIAL_CONSIDERATIONS']

# %%
filtered_df[filtered_cat].nunique()
# Out:
# APPLICATION_TYPE          17
# AFFILIATION                6
# CLASSIFICATION            71
# USE_CASE                   5
# ORGANIZATION               4
# INCOME_AMT                 9
# SPECIAL_CONSIDERATIONS     2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_type = filtered_df['APPLICATION_TYPE'].value_counts().reset_index()
app_type
# Out:
#    index  APPLICATION_TYPE
# 0     T3             27037
# 1     T4              1542
# 2     T6              1216
# 3     T5              1173
# 4    T19              1065
# 5     T8               737
# 6     T7               725
# 7    T10               528
# 8     T9               156
# 9    T13                66
# 10   T12                27
# 11    T2                16
# 12   T25                 3
# 13   T14                 3
# 14   T29                 2
# 15   T15                 2
# 16   T17                 1

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = []
application_types_to_replace = app_type[app_type['APPLICATION_TYPE'] <= 600]['index']

# Replace in dataframe
for app in application_types_to_replace:
    filtered_df['APPLICATION_TYPE'] = filtered_df['APPLICATION_TYPE'].replace(app,"Other")
# Check to make sure binning was successful
filtered_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Other      804
# T8         737
# T7         725
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_count = filtered_df['CLASSIFICATION'].value_counts().reset_index()
class_count
# Out:
#     index  CLASSIFICATION
# 0   C1000           17326
# 1   C2000            6074
# 2   C1200            4837
# 3   C3000            1918
# 4   C2100            1883
# ..    ...             ...
# 66  C4120               1
# 67  C8210               1
# 68  C2561               1
# 69  C4500               1
# 70  C2150               1
#
# [71 rows x 2 columns]

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = []
classifications_to_replace = class_count[class_count['CLASSIFICATION'] < 300]['index']


# Replace in dataframe
for cls in classifications_to_replace:
    filtered_df['CLASSIFICATION'] = filtered_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
filtered_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: CLASSIFICATION, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_count_filtered = []
class_count_filtered = class_count[class_count['CLASSIFICATION'] > 1]
class_count_filtered
# Out:
#     index  CLASSIFICATION
# 0   C1000           17326
# 1   C2000            6074
# 2   C1200            4837
# 3   C3000            1918
# 4   C2100            1883
# 5   C7000             777
# 6   C1700             287
# 7   C4000             194
# 8   C5000             116
# 9   C1270             114
# 10  C2700             104
# 11  C2800              95
# 12  C7100              75
# 13  C1300              58
# 14  C1280              50
# 15  C1230              36
# 16  C1400              34
# 17  C7200              32
# 18  C2300              32
# 19  C1240              30
# 20  C8000              20
# 21  C7120              18
# 22  C1500              16
# 23  C1800              15
# 24  C6000              15
# 25  C1250              14
# 26  C8200              11
# 27  C1238              10
# 28  C1278              10
# 29  C1235               9
# 30  C1237               9
# 31  C7210               7
# 32  C2400               6
# 33  C1720               6
# 34  C4100               6
# 35  C1257               5
# 36  C1600               5
# 37  C1260               3
# 38  C2710               3
# 39     C0               3
# 40  C3200               2
# 41  C1234               2
# 42  C1246               2
# 43  C1267               2
# 44  C1256               2

# %%
# Convert categorical data to numeric with `pd.get_dummies`
numerical_df = pd.get_dummies(filtered_df)
numerical_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       1
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                         0                    0                    0
# 1                         0                    1                    0
# 2                         0                    0                    0
# 3                         0                    1                    0
# 4                         0                    1                    0
# ...                     ...                  ...                  ...
# 34294                     0                    0                    1
# 34295                     0                    0                    1
# 34296                     0                    1                    0
# 34297                     0                    0                    0
# 34298                     0                    1                    0
#
#        APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        1                    0                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    0                    0                    0  ...
# 34295                    0                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    1                    0                    0  ...
# 34298                    0                    0                    0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = numerical_df["IS_SUCCESSFUL"].values
X = numerical_df.drop(["IS_SUCCESSFUL"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
# Out:
# C:\Users\mcado\AppData\Local\Temp\ipykernel_348\120369778.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = numerical_df.drop(["IS_SUCCESSFUL"],1).values

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  9
hidden_nodes_layer2 = 18
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="LeakyReLU")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="LeakyReLU"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 9)                 396
#
#  dense_1 (Dense)             (None, 18)                180
#
#  dense_2 (Dense)             (None, 1)                 19
#
# =================================================================
# Total params: 595
# Trainable params: 595
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 5s 4ms/step - loss: 0.5887 - accuracy: 0.7124
# Epoch 2/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5654 - accuracy: 0.7255
# Epoch 3/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5608 - accuracy: 0.7275
# Epoch 4/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5583 - accuracy: 0.7283
# Epoch 5/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5570 - accuracy: 0.7285
# Epoch 6/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5557 - accuracy: 0.7280
# Epoch 7/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5547 - accuracy: 0.7283
# Epoch 8/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5534 - accuracy: 0.7298
# Epoch 9/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5530 - accuracy: 0.7294
# Epoch 10/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5521 - accuracy: 0.7287
# Epoch 11/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5515 - accuracy: 0.7291
# Epoch 12/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5506 - accuracy: 0.7294
# Epoch 13/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5505 - accuracy: 0.7301
# Epoch 14/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5501 - accuracy: 0.7304
# Epoch 15/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5495 - accuracy: 0.7294
# Epoch 16/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5492 - accuracy: 0.7306
# Epoch 17/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5493 - accuracy: 0.7306
# Epoch 18/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5489 - accuracy: 0.7299
# Epoch 19/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5483 - accuracy: 0.7317
# Epoch 20/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5480 - accuracy: 0.7307
# Epoch 21/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5480 - accuracy: 0.7289
# Epoch 22/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5477 - accuracy: 0.7314
# Epoch 23/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5477 - accuracy: 0.7299
# Epoch 24/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5476 - accuracy: 0.7313
# Epoch 25/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5475 - accuracy: 0.7312
# Epoch 26/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5471 - accuracy: 0.7317
# Epoch 27/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5470 - accuracy: 0.7312
# Epoch 28/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5465 - accuracy: 0.7321
# Epoch 29/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5468 - accuracy: 0.7305
# Epoch 30/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5461 - accuracy: 0.7310
# Epoch 31/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5465 - accuracy: 0.7317
# Epoch 32/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5456 - accuracy: 0.7316
# Epoch 33/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5461 - accuracy: 0.7322
# Epoch 34/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5460 - accuracy: 0.7320
# Epoch 35/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5457 - accuracy: 0.7324
# Epoch 36/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5462 - accuracy: 0.7316
# Epoch 37/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5456 - accuracy: 0.7324
# Epoch 38/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5456 - accuracy: 0.7318
# Epoch 39/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5454 - accuracy: 0.7325
# Epoch 40/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5456 - accuracy: 0.7320
# Epoch 41/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5452 - accuracy: 0.7317
# Epoch 42/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5456 - accuracy: 0.7311
# Epoch 43/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5451 - accuracy: 0.7318
# Epoch 44/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5451 - accuracy: 0.7327
# Epoch 45/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5456 - accuracy: 0.7318
# Epoch 46/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5449 - accuracy: 0.7314
# Epoch 47/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5452 - accuracy: 0.7308
# Epoch 48/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5444 - accuracy: 0.7325
# Epoch 49/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5446 - accuracy: 0.7328
# Epoch 50/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5450 - accuracy: 0.7322
# Epoch 51/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5444 - accuracy: 0.7319
# Epoch 52/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5444 - accuracy: 0.7317
# Epoch 53/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5445 - accuracy: 0.7311
# Epoch 54/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5451 - accuracy: 0.7312
# Epoch 55/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5448 - accuracy: 0.7320
# Epoch 56/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5447 - accuracy: 0.7310
# Epoch 57/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5442 - accuracy: 0.7325
# Epoch 58/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5440 - accuracy: 0.7316
# Epoch 59/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5445 - accuracy: 0.7320
# Epoch 60/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5438 - accuracy: 0.7313
# Epoch 61/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5445 - accuracy: 0.7315
# Epoch 62/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5444 - accuracy: 0.7309
# Epoch 63/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5445 - accuracy: 0.7309
# Epoch 64/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5438 - accuracy: 0.7331
# Epoch 65/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5439 - accuracy: 0.7316
# Epoch 66/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5439 - accuracy: 0.7335
# Epoch 67/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5437 - accuracy: 0.7334
# Epoch 68/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5440 - accuracy: 0.7310
# Epoch 69/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5437 - accuracy: 0.7320
# Epoch 70/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5440 - accuracy: 0.7316
# Epoch 71/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5437 - accuracy: 0.7311
# Epoch 72/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5437 - accuracy: 0.7318
# Epoch 73/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5443 - accuracy: 0.7326
# Epoch 74/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5439 - accuracy: 0.7337
# Epoch 75/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5438 - accuracy: 0.7320
# Epoch 76/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5435 - accuracy: 0.7338
# Epoch 77/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5438 - accuracy: 0.7330
# Epoch 78/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5437 - accuracy: 0.7315
# Epoch 79/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5436 - accuracy: 0.7323
# Epoch 80/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5436 - accuracy: 0.7336
# Epoch 81/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5436 - accuracy: 0.7314
# Epoch 82/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5437 - accuracy: 0.7317
# Epoch 83/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5436 - accuracy: 0.7338
# Epoch 84/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5437 - accuracy: 0.7336
# Epoch 85/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5435 - accuracy: 0.7336
# Epoch 86/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5433 - accuracy: 0.7324
# Epoch 87/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5434 - accuracy: 0.7327
# Epoch 88/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5433 - accuracy: 0.7328
# Epoch 89/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5433 - accuracy: 0.7338
# Epoch 90/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5435 - accuracy: 0.7324
# Epoch 91/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5431 - accuracy: 0.7334
# Epoch 92/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5433 - accuracy: 0.7320
# Epoch 93/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5433 - accuracy: 0.7336
# Epoch 94/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5432 - accuracy: 0.7318
# Epoch 95/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5434 - accuracy: 0.7318
# Epoch 96/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5433 - accuracy: 0.7329
# Epoch 97/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5431 - accuracy: 0.7323
# Epoch 98/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5433 - accuracy: 0.7327
# Epoch 99/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5435 - accuracy: 0.7318
# Epoch 100/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5434 - accuracy: 0.7324

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history)

# Increase the index by 1 to match the number of epochs
history_df.index += 1

# Plot the loss
history_df.plot(y="loss")
# Out:
# <AxesSubplot:>

# %%
# Plot the accuracy
history_df.plot(y="accuracy")
# Out:
# <AxesSubplot:>

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5541 - accuracy: 0.7259 - 1s/epoch - 4ms/step
# Loss: 0.5540710687637329, Accuracy: 0.7259474992752075

# %%
# Export our model to HDF5 file
nn.save('AlphabetSoupCharity.h5')
